# %% [markdown]
# # AWS CloudFortmation to Terraform Resources

# %%
from typing import List, Any

import re
import json
import requests
import urllib.parse
import functools

from bs4 import BeautifulSoup
from lxml import etree

# %%
def dump_json(filename: str, data: Any):
    with open(filename, "w") as outfile:
        outfile.write(json.dumps(data, indent=2))

# %% [markdown]
# ## Terraform AWS Provider Docs
#
# [Reference Documentation](https://registry.terraform.io/providers/hashicorp/aws/latest/docs)

# %%
AWS_PROVIDER_VERSION = "16565" # terraform-provider-aws v3.63.0
AWS_PROVIDER_DOCS_URL = (
    "https://registry.terraform.io/v2/provider-versions/"
    f"{AWS_PROVIDER_VERSION}?include=provider-docs")

aws_provider_docs = requests.get(AWS_PROVIDER_DOCS_URL).json()

aws_provider_resources = list(filter(
    lambda item: item["attributes"]["category"] == "resources", aws_provider_docs["included"]
))

# %%
aws_tf_resources = set(map(lambda item: "aws_" + item["attributes"]["title"], aws_provider_resources))

# %%
dump_json("dumps/aws_terraform_provider_docs.json", aws_provider_docs)

# %%
dump_json("dumps/aws_tf_resources.json", sorted(aws_tf_resources))

# %% [markdown]
# ---
#
# ## AWS CloudFormation Resources
#
# [Reference Documentation](https://docs.aws.amazon.com/AWSCloudFormation/latest/UserGuide/aws-template-resource-type-ref.html)

# %%
AWS_REF_URL = ("https://docs.aws.amazon.com/AWSCloudFormation/latest/"
               "UserGuide/aws-template-resource-type-ref.html")
AWS_TOC_URL = "https://docs.aws.amazon.com/AWSCloudFormation/latest/UserGuide/toc-{service}.json"

# %%
ref_docs_body = requests.get(AWS_REF_URL).text

# %%
soup = BeautifulSoup(ref_docs_body, "html.parser")
dom = etree.HTML(str(soup))

# %%
def parse_toc(contents: List[Any]):
    resources = []
    for item in contents:
        if "AWS::" in item.get("title", ""):
            resources.append(item["title"])

        if len(item.get("contents", [])):
            resources.extend(parse_toc(item["contents"]))
    return resources

# %%
aws_cloud_formation_resource_docs = {}
aws_cloud_formation_resources = []

for link in dom.xpath('//*[@class="highlights"]/ul/li/a'):
    service = link.get("href").replace("./", "").split(".")[0]
    try:
        resource_toc = requests.get(AWS_TOC_URL.format(service=service)).json()
        aws_cloud_formation_resource_docs[service] = resource_toc
        aws_cloud_formation_resources.extend(parse_toc(resource_toc["contents"]))
    except json.decoder.JSONDecodeError:
        print(f"Unable to parse the following: {service}")
# Out:
# Unable to parse the following: cfn-reference-shared

# %%
aws_cloud_formation_resource_docs
# Out:
# {'AWS_ACMPCA': {'contents': [{'title': 'ACM PCA',
#     'href': 'AWS_ACMPCA.html',
#     'contents': [{'title': 'AWS::ACMPCA::Certificate',
#       'href': 'aws-resource-acmpca-certificate.html',
#       'contents': [{'title': 'ApiPassthrough',
#         'href': 'aws-properties-acmpca-certificate-apipassthrough.html'},
#        {'title': 'EdiPartyName',
#         'href': 'aws-properties-acmpca-certificate-edipartyname.html'},
#        {'title': 'ExtendedKeyUsage',
#         'href': 'aws-properties-acmpca-certificate-extendedkeyusage.html'},
#        {'title': 'Extensions',
#         'href': 'aws-properties-acmpca-certificate-extensions.html'},
#        {'title': 'GeneralName',
#         'href': 'aws-properties-acmpca-certificate-generalname.html'},
#        {'title': 'KeyUsage',
#         'href': 'aws-properties-acmpca-certificate-keyusage.html'},
#        {'title': 'OtherName',
#         'href': 'aws-properties-acmpca-certificate-othername.html'},
#        {'title': 'PolicyInformation',
#         'href': 'aws-properties-acmpca-certificate-policyinformation.html'},
#        {'title': 'PolicyQualifierInfo',
#         'href': 'aws-properties-acmpca-certificate-policyqualifierinfo.html'},
#        {'title': 'Qualifier',
#         'href': 'aws-properties-acmpca-certificate-qualifier.html'},
#        {'title': 'Subject',
#         'href': 'aws-properties-acmpca-certificate-subject.html'},
#        {'title': 'Validity',
#         'href': 'aws-properties-acmpca-certificate-validity.html'}]},
#      {'title': 'AWS::ACMPCA::CertificateAuthority',
#       'href': 'aws-resource-acmpca-certificateauthority.html',
#       'contents': [{'title': 'AccessDescription',
#         'href': 'aws-properties-acmpca-certificateauthority-accessdescription.html'},
#        {'title': 'AccessMethod',
#         'href': 'aws-properties-acmpca-certificateauthority-accessmethod.html'},
#        {'title': 'CrlConfiguration',
#         'href': 'aws-properties-acmpca-certificateauthority-crlconfiguration.html'},
#        {'title': 'CsrExtensions',
#         'href': 'aws-properties-acmpca-certificateauthority-csrextensions.html'},
#        {'title': 'EdiPartyName',
#         'href': 'aws-properties-acmpca-certificateauthority-edipartyname.html'},
#        {'title': 'GeneralName',
#         'href': 'aws-properties-acmpca-certificateauthority-generalname.html'},
#        {'title': 'KeyUsage',
#         'href': 'aws-properties-acmpca-certificateauthority-keyusage.html'},
#        {'title': 'OcspConfiguration',
#         'href': 'aws-properties-acmpca-certificateauthority-ocspconfiguration.html'},
#        {'title': 'OtherName',
#         'href': 'aws-properties-acmpca-certificateauthority-othername.html'},
#        {'title': 'RevocationConfiguration',
#         'href': 'aws-properties-acmpca-certificateauthority-revocationconfiguration.html'},
#        {'title': 'Subject',
#         'href': 'aws-properties-acmpca-certificateauthority-subject.html'}]},
#      {'title': 'AWS::ACMPCA::CertificateAuthorityActivation',
#       'href': 'aws-resource-acmpca-certificateauthorityactivation.html'},
#      {'title': 'AWS::ACMPCA::Permission',
#       'href': 'aws-resource-acmpca-permission.html'}]}]},
#  'AWS_Amplify': {'contents': [{'title': 'Amplify Console',
#     'href': 'AWS_Amplify.html',
#     'contents': [{'title': 'AWS::Amplify::App',
#       'href': 'aws-resource-amplify-app.html',
#       'contents': [{'title': 'AutoBranchCreationConfig',
#         'href': 'aws-properties-amplify-app-autobranchcreationconfig.html'},
#        {'title': 'BasicAuthConfig',
#         'href': 'aws-properties-amplify-app-basicauthconfig.html'},
#        {'title': 'CustomRule',
#         'href': 'aws-properties-amplify-app-customrule.html'},
#        {'title': 'EnvironmentVariable',
#         'href': 'aws-properties-amplify-app-environmentvariable.html'}]},
#      {'title': 'AWS::Amplify::Branch',
#       'href': 'aws-resource-amplify-branch.html',
#       'contents': [{'title': 'BasicAuthConfig',
#         'href': 'aws-properties-amplify-branch-basicauthconfig.html'},
#        {'title': 'EnvironmentVariable',
#         'href': 'aws-properties-amplify-branch-environmentvariable.html'}]},
#      {'title': 'AWS::Amplify::Domain',
#       'href': 'aws-resource-amplify-domain.html',
#       'contents': [{'title': 'SubDomainSetting',
#         'href': 'aws-properties-amplify-domain-subdomainsetting.html'}]}]}]},
#  'AWS_ApiGateway': {'contents': [{'title': 'API Gateway',
#     'href': 'AWS_ApiGateway.html',
#     'contents': [{'title': 'AWS::ApiGateway::Account',
#       'href': 'aws-resource-apigateway-account.html'},
#      {'title': 'AWS::ApiGateway::ApiKey',
#       'href': 'aws-resource-apigateway-apikey.html',
#       'contents': [{'title': 'StageKey',
#         'href': 'aws-properties-apigateway-apikey-stagekey.html'}]},
#      {'title': 'AWS::ApiGateway::Authorizer',
#       'href': 'aws-resource-apigateway-authorizer.html'},
#      {'title': 'AWS::ApiGateway::BasePathMapping',
#       'href': 'aws-resource-apigateway-basepathmapping.html'},
#      {'title': 'AWS::ApiGateway::ClientCertificate',
#       'href': 'aws-resource-apigateway-clientcertificate.html'},
#      {'title': 'AWS::ApiGateway::Deployment',
#       'href': 'aws-resource-apigateway-deployment.html',
#       'contents': [{'title': 'AccessLogSetting',
#         'href': 'aws-properties-apigateway-deployment-accesslogsetting.html'},
#        {'title': 'CanarySetting',
#         'href': 'aws-properties-apigateway-deployment-canarysetting.html'},
#        {'title': 'DeploymentCanarySettings',
#         'href': 'aws-properties-apigateway-deployment-deploymentcanarysettings.html'},
#        {'title': 'MethodSetting',
#         'href': 'aws-properties-apigateway-deployment-stagedescription-methodsetting.html'},
#        {'title': 'StageDescription',
#         'href': 'aws-properties-apigateway-deployment-stagedescription.html'}]},
#      {'title': 'AWS::ApiGateway::DocumentationPart',
#       'href': 'aws-resource-apigateway-documentationpart.html',
#       'contents': [{'title': 'Location',
#         'href': 'aws-properties-apigateway-documentationpart-location.html'}]},
#      {'title': 'AWS::ApiGateway::DocumentationVersion',
#       'href': 'aws-resource-apigateway-documentationversion.html'},
#      {'title': 'AWS::ApiGateway::DomainName',
#       'href': 'aws-resource-apigateway-domainname.html',
#       'contents': [{'title': 'EndpointConfiguration',
#         'href': 'aws-properties-apigateway-domainname-endpointconfiguration.html'},
#        {'title': 'MutualTlsAuthentication',
#         'href': 'aws-properties-apigateway-domainname-mutualtlsauthentication.html'}]},
#      {'title': 'AWS::ApiGateway::GatewayResponse',
#       'href': 'aws-resource-apigateway-gatewayresponse.html'},
#      {'title': 'AWS::ApiGateway::Method',
#       'href': 'aws-resource-apigateway-method.html',
#       'contents': [{'title': 'Integration',
#         'href': 'aws-properties-apitgateway-method-integration.html'},
#        {'title': 'IntegrationResponse',
#         'href': 'aws-properties-apitgateway-method-integration-integrationresponse.html'},
#        {'title': 'MethodResponse',
#         'href': 'aws-properties-apitgateway-method-methodresponse.html'}]},
#      {'title': 'AWS::ApiGateway::Model',
#       'href': 'aws-resource-apigateway-model.html'},
#      {'title': 'AWS::ApiGateway::RequestValidator',
#       'href': 'aws-resource-apigateway-requestvalidator.html'},
#      {'title': 'AWS::ApiGateway::Resource',
#       'href': 'aws-resource-apigateway-resource.html'},
#      {'title': 'AWS::ApiGateway::RestApi',
#       'href': 'aws-resource-apigateway-restapi.html',
#       'contents': [{'title': 'EndpointConfiguration',
#         'href': 'aws-properties-apigateway-restapi-endpointconfiguration.html'},
#        {'title': 'S3Location',
#         'href': 'aws-properties-apigateway-restapi-s3location.html'}]},
#      {'title': 'AWS::ApiGateway::Stage',
#       'href': 'aws-resource-apigateway-stage.html',
#       'contents': [{'title': 'AccessLogSetting',
#         'href': 'aws-properties-apigateway-stage-accesslogsetting.html'},
#        {'title': 'CanarySetting',
#         'href': 'aws-properties-apigateway-stage-canarysetting.html'},
#        {'title': 'MethodSetting',
#         'href': 'aws-properties-apitgateway-stage-methodsetting.html'}]},
#      {'title': 'AWS::ApiGateway::UsagePlan',
#       'href': 'aws-resource-apigateway-usageplan.html',
#       'contents': [{'title': 'ApiStage',
#         'href': 'aws-properties-apigateway-usageplan-apistage.html'},
#        {'title': 'QuotaSettings',
#         'href': 'aws-properties-apigateway-usageplan-quotasettings.html'},
#        {'title': 'ThrottleSettings',
#         'href': 'aws-properties-apigateway-usageplan-throttlesettings.html'}]},
#      {'title': 'AWS::ApiGateway::UsagePlanKey',
#       'href': 'aws-resource-apigateway-usageplankey.html'},
#      {'title': 'AWS::ApiGateway::VpcLink',
#       'href': 'aws-resource-apigateway-vpclink.html'}]}]},
#  'AWS_ApiGatewayV2': {'contents': [{'title': 'API Gateway V2',
#     'href': 'AWS_ApiGatewayV2.html',
#     'contents': [{'title': 'AWS::ApiGatewayV2::Api',
#       'href': 'aws-resource-apigatewayv2-api.html',
#       'contents': [{'title': 'BodyS3Location',
#         'href': 'aws-properties-apigatewayv2-api-bodys3location.html'},
#        {'title': 'Cors',
#         'href': 'aws-properties-apigatewayv2-api-cors.html'}]},
#      {'title': 'AWS::ApiGatewayV2::ApiGatewayManagedOverrides',
#       'href': 'aws-resource-apigatewayv2-apigatewaymanagedoverrides.html',
#       'contents': [{'title': 'AccessLogSettings',
#         'href': 'aws-properties-apigatewayv2-apigatewaymanagedoverrides-accesslogsettings.html'},
#        {'title': 'IntegrationOverrides',
#         'href': 'aws-properties-apigatewayv2-apigatewaymanagedoverrides-integrationoverrides.html'},
#        {'title': 'RouteOverrides',
#         'href': 'aws-properties-apigatewayv2-apigatewaymanagedoverrides-routeoverrides.html'},
#        {'title': 'RouteSettings',
#         'href': 'aws-properties-apigatewayv2-apigatewaymanagedoverrides-routesettings.html'},
#        {'title': 'StageOverrides',
#         'href': 'aws-properties-apigatewayv2-apigatewaymanagedoverrides-stageoverrides.html'}]},
#      {'title': 'AWS::ApiGatewayV2::ApiMapping',
#       'href': 'aws-resource-apigatewayv2-apimapping.html'},
#      {'title': 'AWS::ApiGatewayV2::Authorizer',
#       'href': 'aws-resource-apigatewayv2-authorizer.html',
#       'contents': [{'title': 'JWTConfiguration',
#         'href': 'aws-properties-apigatewayv2-authorizer-jwtconfiguration.html'}]},
#      {'title': 'AWS::ApiGatewayV2::Deployment',
#       'href': 'aws-resource-apigatewayv2-deployment.html'},
#      {'title': 'AWS::ApiGatewayV2::DomainName',
#       'href': 'aws-resource-apigatewayv2-domainname.html',
#       'contents': [{'title': 'DomainNameConfiguration',
#         'href': 'aws-properties-apigatewayv2-domainname-domainnameconfiguration.html'},
#        {'title': 'MutualTlsAuthentication',
#         'href': 'aws-properties-apigatewayv2-domainname-mutualtlsauthentication.html'}]},
#      {'title': 'AWS::ApiGatewayV2::Integration',
#       'href': 'aws-resource-apigatewayv2-integration.html',
#       'contents': [{'title': 'ResponseParameter',
#         'href': 'aws-properties-apigatewayv2-integration-responseparameter.html'},
#        {'title': 'ResponseParameterList',
#         'href': 'aws-properties-apigatewayv2-integration-responseparameterlist.html'},
#        {'title': 'TlsConfig',
#         'href': 'aws-properties-apigatewayv2-integration-tlsconfig.html'}]},
#      {'title': 'AWS::ApiGatewayV2::IntegrationResponse',
#       'href': 'aws-resource-apigatewayv2-integrationresponse.html'},
#      {'title': 'AWS::ApiGatewayV2::Model',
#       'href': 'aws-resource-apigatewayv2-model.html'},
#      {'title': 'AWS::ApiGatewayV2::Route',
#       'href': 'aws-resource-apigatewayv2-route.html',
#       'contents': [{'title': 'ParameterConstraints',
#         'href': 'aws-properties-apigatewayv2-route-parameterconstraints.html'}]},
#      {'title': 'AWS::ApiGatewayV2::RouteResponse',
#       'href': 'aws-resource-apigatewayv2-routeresponse.html',
#       'contents': [{'title': 'ParameterConstraints',
#         'href': 'aws-properties-apigatewayv2-routeresponse-parameterconstraints.html'}]},
#      {'title': 'AWS::ApiGatewayV2::Stage',
#       'href': 'aws-resource-apigatewayv2-stage.html',
#       'contents': [{'title': 'AccessLogSettings',
#         'href': 'aws-properties-apigatewayv2-stage-accesslogsettings.html'},
#        {'title': 'RouteSettings',
#         'href': 'aws-properties-apigatewayv2-stage-routesettings.html'}]},
#      {'title': 'AWS::ApiGatewayV2::VpcLink',
#       'href': 'aws-resource-apigatewayv2-vpclink.html'}]}]},
#  'AWS_AppConfig': {'contents': [{'title': 'AppConfig',
#     'href': 'AWS_AppConfig.html',
#     'contents': [{'title': 'AWS::AppConfig::Application',
#       'href': 'aws-resource-appconfig-application.html',
#       'contents': [{'title': 'Tags',
#         'href': 'aws-properties-appconfig-application-tags.html'}]},
#      {'title': 'AWS::AppConfig::ConfigurationProfile',
#       'href': 'aws-resource-appconfig-configurationprofile.html',
#       'contents': [{'title': 'Tags',
#         'href': 'aws-properties-appconfig-configurationprofile-tags.html'},
#        {'title': 'Validators',
#         'href': 'aws-properties-appconfig-configurationprofile-validators.html'}]},
#      {'title': 'AWS::AppConfig::Deployment',
#       'href': 'aws-resource-appconfig-deployment.html',
#       'contents': [{'title': 'Tags',
#         'href': 'aws-properties-appconfig-deployment-tags.html'}]},
#      {'title': 'AWS::AppConfig::DeploymentStrategy',
#       'href': 'aws-resource-appconfig-deploymentstrategy.html',
#       'contents': [{'title': 'Tags',
#         'href': 'aws-properties-appconfig-deploymentstrategy-tags.html'}]},
#      {'title': 'AWS::AppConfig::Environment',
#       'href': 'aws-resource-appconfig-environment.html',
#       'contents': [{'title': 'Monitors',
#         'href': 'aws-properties-appconfig-environment-monitors.html'},
#        {'title': 'Tags',
#         'href': 'aws-properties-appconfig-environment-tags.html'}]},
#      {'title': 'AWS::AppConfig::HostedConfigurationVersion',
#       'href': 'aws-resource-appconfig-hostedconfigurationversion.html'}]}]},
#  'AWS_AppFlow': {'contents': [{'title': 'Amazon AppFlow',
#     'href': 'AWS_AppFlow.html',
#     'contents': [{'title': 'AWS::AppFlow::ConnectorProfile',
#       'href': 'aws-resource-appflow-connectorprofile.html',
#       'contents': [{'title': 'AmplitudeConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-amplitudeconnectorprofilecredentials.html'},
#        {'title': 'ConnectorOAuthRequest',
#         'href': 'aws-properties-appflow-connectorprofile-connectoroauthrequest.html'},
#        {'title': 'ConnectorProfileConfig',
#         'href': 'aws-properties-appflow-connectorprofile-connectorprofileconfig.html'},
#        {'title': 'ConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-connectorprofilecredentials.html'},
#        {'title': 'ConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-connectorprofileproperties.html'},
#        {'title': 'DatadogConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-datadogconnectorprofilecredentials.html'},
#        {'title': 'DatadogConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-datadogconnectorprofileproperties.html'},
#        {'title': 'DynatraceConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-dynatraceconnectorprofilecredentials.html'},
#        {'title': 'DynatraceConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-dynatraceconnectorprofileproperties.html'},
#        {'title': 'GoogleAnalyticsConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-googleanalyticsconnectorprofilecredentials.html'},
#        {'title': 'InforNexusConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-infornexusconnectorprofilecredentials.html'},
#        {'title': 'InforNexusConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-infornexusconnectorprofileproperties.html'},
#        {'title': 'MarketoConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-marketoconnectorprofilecredentials.html'},
#        {'title': 'MarketoConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-marketoconnectorprofileproperties.html'},
#        {'title': 'OAuthProperties',
#         'href': 'aws-properties-appflow-connectorprofile-oauthproperties.html'},
#        {'title': 'RedshiftConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-redshiftconnectorprofilecredentials.html'},
#        {'title': 'RedshiftConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-redshiftconnectorprofileproperties.html'},
#        {'title': 'SalesforceConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-salesforceconnectorprofilecredentials.html'},
#        {'title': 'SalesforceConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-salesforceconnectorprofileproperties.html'},
#        {'title': 'SAPODataConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-sapodataconnectorprofilecredentials.html'},
#        {'title': 'SAPODataConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-sapodataconnectorprofileproperties.html'},
#        {'title': 'ServiceNowConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-servicenowconnectorprofilecredentials.html'},
#        {'title': 'ServiceNowConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-servicenowconnectorprofileproperties.html'},
#        {'title': 'SingularConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-singularconnectorprofilecredentials.html'},
#        {'title': 'SlackConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-slackconnectorprofilecredentials.html'},
#        {'title': 'SlackConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-slackconnectorprofileproperties.html'},
#        {'title': 'SnowflakeConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-snowflakeconnectorprofilecredentials.html'},
#        {'title': 'SnowflakeConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-snowflakeconnectorprofileproperties.html'},
#        {'title': 'TrendmicroConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-trendmicroconnectorprofilecredentials.html'},
#        {'title': 'VeevaConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-veevaconnectorprofilecredentials.html'},
#        {'title': 'VeevaConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-veevaconnectorprofileproperties.html'},
#        {'title': 'ZendeskConnectorProfileCredentials',
#         'href': 'aws-properties-appflow-connectorprofile-zendeskconnectorprofilecredentials.html'},
#        {'title': 'ZendeskConnectorProfileProperties',
#         'href': 'aws-properties-appflow-connectorprofile-zendeskconnectorprofileproperties.html'}]},
#      {'title': 'AWS::AppFlow::Flow',
#       'href': 'aws-resource-appflow-flow.html',
#       'contents': [{'title': 'AggregationConfig',
#         'href': 'aws-properties-appflow-flow-aggregationconfig.html'},
#        {'title': 'AmplitudeSourceProperties',
#         'href': 'aws-properties-appflow-flow-amplitudesourceproperties.html'},
#        {'title': 'ConnectorOperator',
#         'href': 'aws-properties-appflow-flow-connectoroperator.html'},
#        {'title': 'DatadogSourceProperties',
#         'href': 'aws-properties-appflow-flow-datadogsourceproperties.html'},
#        {'title': 'DestinationConnectorProperties',
#         'href': 'aws-properties-appflow-flow-destinationconnectorproperties.html'},
#        {'title': 'DestinationFlowConfig',
#         'href': 'aws-properties-appflow-flow-destinationflowconfig.html'},
#        {'title': 'DynatraceSourceProperties',
#         'href': 'aws-properties-appflow-flow-dynatracesourceproperties.html'},
#        {'title': 'ErrorHandlingConfig',
#         'href': 'aws-properties-appflow-flow-errorhandlingconfig.html'},
#        {'title': 'EventBridgeDestinationProperties',
#         'href': 'aws-properties-appflow-flow-eventbridgedestinationproperties.html'},
#        {'title': 'GoogleAnalyticsSourceProperties',
#         'href': 'aws-properties-appflow-flow-googleanalyticssourceproperties.html'},
#        {'title': 'IncrementalPullConfig',
#         'href': 'aws-properties-appflow-flow-incrementalpullconfig.html'},
#        {'title': 'InforNexusSourceProperties',
#         'href': 'aws-properties-appflow-flow-infornexussourceproperties.html'},
#        {'title': 'LookoutMetricsDestinationProperties',
#         'href': 'aws-properties-appflow-flow-lookoutmetricsdestinationproperties.html'},
#        {'title': 'MarketoSourceProperties',
#         'href': 'aws-properties-appflow-flow-marketosourceproperties.html'},
#        {'title': 'PrefixConfig',
#         'href': 'aws-properties-appflow-flow-prefixconfig.html'},
#        {'title': 'RedshiftDestinationProperties',
#         'href': 'aws-properties-appflow-flow-redshiftdestinationproperties.html'},
#        {'title': 'S3DestinationProperties',
#         'href': 'aws-properties-appflow-flow-s3destinationproperties.html'},
#        {'title': 'S3InputFormatConfig',
#         'href': 'aws-properties-appflow-flow-s3inputformatconfig.html'},
#        {'title': 'S3OutputFormatConfig',
#         'href': 'aws-properties-appflow-flow-s3outputformatconfig.html'},
#        {'title': 'S3SourceProperties',
#         'href': 'aws-properties-appflow-flow-s3sourceproperties.html'},
#        {'title': 'SalesforceDestinationProperties',
#         'href': 'aws-properties-appflow-flow-salesforcedestinationproperties.html'},
#        {'title': 'SalesforceSourceProperties',
#         'href': 'aws-properties-appflow-flow-salesforcesourceproperties.html'},
#        {'title': 'SAPODataSourceProperties',
#         'href': 'aws-properties-appflow-flow-sapodatasourceproperties.html'},
#        {'title': 'ScheduledTriggerProperties',
#         'href': 'aws-properties-appflow-flow-scheduledtriggerproperties.html'},
#        {'title': 'ServiceNowSourceProperties',
#         'href': 'aws-properties-appflow-flow-servicenowsourceproperties.html'},
#        {'title': 'SingularSourceProperties',
#         'href': 'aws-properties-appflow-flow-singularsourceproperties.html'},
#        {'title': 'SlackSourceProperties',
#         'href': 'aws-properties-appflow-flow-slacksourceproperties.html'},
#        {'title': 'SnowflakeDestinationProperties',
#         'href': 'aws-properties-appflow-flow-snowflakedestinationproperties.html'},
#        {'title': 'SourceConnectorProperties',
#         'href': 'aws-properties-appflow-flow-sourceconnectorproperties.html'},
#        {'title': 'SourceFlowConfig',
#         'href': 'aws-properties-appflow-flow-sourceflowconfig.html'},
#        {'title': 'Task', 'href': 'aws-properties-appflow-flow-task.html'},
#        {'title': 'TaskPropertiesObject',
#         'href': 'aws-properties-appflow-flow-taskpropertiesobject.html'},
#        {'title': 'TrendmicroSourceProperties',
#         'href': 'aws-properties-appflow-flow-trendmicrosourceproperties.html'},
#        {'title': 'TriggerConfig',
#         'href': 'aws-properties-appflow-flow-triggerconfig.html'},
#        {'title': 'UpsolverDestinationProperties',
#         'href': 'aws-properties-appflow-flow-upsolverdestinationproperties.html'},
#        {'title': 'UpsolverS3OutputFormatConfig',
#         'href': 'aws-properties-appflow-flow-upsolvers3outputformatconfig.html'},
#        {'title': 'VeevaSourceProperties',
#         'href': 'aws-properties-appflow-flow-veevasourceproperties.html'},
#        {'title': 'ZendeskDestinationProperties',
#         'href': 'aws-properties-appflow-flow-zendeskdestinationproperties.html'},
#        {'title': 'ZendeskSourceProperties',
#         'href': 'aws-properties-appflow-flow-zendesksourceproperties.html'}]}]}]},
#  'AWS_AppIntegrations': {'contents': [{'title': 'AppIntegrations',
#     'href': 'AWS_AppIntegrations.html',
#     'contents': [{'title': 'AWS::AppIntegrations::EventIntegration',
#       'href': 'aws-resource-appintegrations-eventintegration.html',
#       'contents': [{'title': 'EventFilter',
#         'href': 'aws-properties-appintegrations-eventintegration-eventfilter.html'},
#        {'title': 'EventIntegrationAssociation',
#         'href': 'aws-properties-appintegrations-eventintegration-eventintegrationassociation.html'},
#        {'title': 'Metadata',
#         'href': 'aws-properties-appintegrations-eventintegration-metadata.html'}]}]}]},
#  'AWS_ApplicationAutoScaling': {'contents': [{'title': 'Application Auto Scaling',
#     'href': 'AWS_ApplicationAutoScaling.html',
#     'contents': [{'title': 'AWS::ApplicationAutoScaling::ScalableTarget',
#       'href': 'aws-resource-applicationautoscaling-scalabletarget.html',
#       'contents': [{'title': 'ScalableTargetAction',
#         'href': 'aws-properties-applicationautoscaling-scalabletarget-scalabletargetaction.html'},
#        {'title': 'ScheduledAction',
#         'href': 'aws-properties-applicationautoscaling-scalabletarget-scheduledaction.html'},
#        {'title': 'SuspendedState',
#         'href': 'aws-properties-applicationautoscaling-scalabletarget-suspendedstate.html'}]},
#      {'title': 'AWS::ApplicationAutoScaling::ScalingPolicy',
#       'href': 'aws-resource-applicationautoscaling-scalingpolicy.html',
#       'contents': [{'title': 'CustomizedMetricSpecification',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-customizedmetricspecification.html'},
#        {'title': 'MetricDimension',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-metricdimension.html'},
#        {'title': 'PredefinedMetricSpecification',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-predefinedmetricspecification.html'},
#        {'title': 'StepAdjustment',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-stepscalingpolicyconfiguration-stepadjustment.html'},
#        {'title': 'StepScalingPolicyConfiguration',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-stepscalingpolicyconfiguration.html'},
#        {'title': 'TargetTrackingScalingPolicyConfiguration',
#         'href': 'aws-properties-applicationautoscaling-scalingpolicy-targettrackingscalingpolicyconfiguration.html'}]}]}]},
#  'AWS_AppMesh': {'contents': [{'title': 'App Mesh',
#     'href': 'AWS_AppMesh.html',
#     'contents': [{'title': 'AWS::AppMesh::GatewayRoute',
#       'href': 'aws-resource-appmesh-gatewayroute.html',
#       'contents': [{'title': 'GatewayRouteHostnameMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutehostnamematch.html'},
#        {'title': 'GatewayRouteHostnameRewrite',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutehostnamerewrite.html'},
#        {'title': 'GatewayRouteMetadataMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutemetadatamatch.html'},
#        {'title': 'GatewayRouteRangeMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayrouterangematch.html'},
#        {'title': 'GatewayRouteSpec',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutespec.html'},
#        {'title': 'GatewayRouteTarget',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutetarget.html'},
#        {'title': 'GatewayRouteVirtualService',
#         'href': 'aws-properties-appmesh-gatewayroute-gatewayroutevirtualservice.html'},
#        {'title': 'GrpcGatewayRoute',
#         'href': 'aws-properties-appmesh-gatewayroute-grpcgatewayroute.html'},
#        {'title': 'GrpcGatewayRouteAction',
#         'href': 'aws-properties-appmesh-gatewayroute-grpcgatewayrouteaction.html'},
#        {'title': 'GrpcGatewayRouteMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-grpcgatewayroutematch.html'},
#        {'title': 'GrpcGatewayRouteMetadata',
#         'href': 'aws-properties-appmesh-gatewayroute-grpcgatewayroutemetadata.html'},
#        {'title': 'GrpcGatewayRouteRewrite',
#         'href': 'aws-properties-appmesh-gatewayroute-grpcgatewayrouterewrite.html'},
#        {'title': 'HttpGatewayRoute',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayroute.html'},
#        {'title': 'HttpGatewayRouteAction',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayrouteaction.html'},
#        {'title': 'HttpGatewayRouteHeader',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayrouteheader.html'},
#        {'title': 'HttpGatewayRouteHeaderMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayrouteheadermatch.html'},
#        {'title': 'HttpGatewayRouteMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayroutematch.html'},
#        {'title': 'HttpGatewayRoutePathRewrite',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayroutepathrewrite.html'},
#        {'title': 'HttpGatewayRoutePrefixRewrite',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayrouteprefixrewrite.html'},
#        {'title': 'HttpGatewayRouteRewrite',
#         'href': 'aws-properties-appmesh-gatewayroute-httpgatewayrouterewrite.html'},
#        {'title': 'HttpPathMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-httppathmatch.html'},
#        {'title': 'HttpQueryParameterMatch',
#         'href': 'aws-properties-appmesh-gatewayroute-httpqueryparametermatch.html'},
#        {'title': 'QueryParameter',
#         'href': 'aws-properties-appmesh-gatewayroute-queryparameter.html'}]},
#      {'title': 'AWS::AppMesh::Mesh',
#       'href': 'aws-resource-appmesh-mesh.html',
#       'contents': [{'title': 'EgressFilter',
#         'href': 'aws-properties-appmesh-mesh-egressfilter.html'},
#        {'title': 'MeshSpec',
#         'href': 'aws-properties-appmesh-mesh-meshspec.html'}]},
#      {'title': 'AWS::AppMesh::Route',
#       'href': 'aws-resource-appmesh-route.html',
#       'contents': [{'title': 'Duration',
#         'href': 'aws-properties-appmesh-route-duration.html'},
#        {'title': 'GrpcRetryPolicy',
#         'href': 'aws-properties-appmesh-route-grpcretrypolicy.html'},
#        {'title': 'GrpcRoute',
#         'href': 'aws-properties-appmesh-route-grpcroute.html'},
#        {'title': 'GrpcRouteAction',
#         'href': 'aws-properties-appmesh-route-grpcrouteaction.html'},
#        {'title': 'GrpcRouteMatch',
#         'href': 'aws-properties-appmesh-route-grpcroutematch.html'},
#        {'title': 'GrpcRouteMetadata',
#         'href': 'aws-properties-appmesh-route-grpcroutemetadata.html'},
#        {'title': 'GrpcRouteMetadataMatchMethod',
#         'href': 'aws-properties-appmesh-route-grpcroutemetadatamatchmethod.html'},
#        {'title': 'GrpcTimeout',
#         'href': 'aws-properties-appmesh-route-grpctimeout.html'},
#        {'title': 'HeaderMatchMethod',
#         'href': 'aws-properties-appmesh-route-headermatchmethod.html'},
#        {'title': 'HttpPathMatch',
#         'href': 'aws-properties-appmesh-route-httppathmatch.html'},
#        {'title': 'HttpQueryParameterMatch',
#         'href': 'aws-properties-appmesh-route-httpqueryparametermatch.html'},
#        {'title': 'HttpRetryPolicy',
#         'href': 'aws-properties-appmesh-route-httpretrypolicy.html'},
#        {'title': 'HttpRoute',
#         'href': 'aws-properties-appmesh-route-httproute.html'},
#        {'title': 'HttpRouteAction',
#         'href': 'aws-properties-appmesh-route-httprouteaction.html'},
#        {'title': 'HttpRouteHeader',
#         'href': 'aws-properties-appmesh-route-httprouteheader.html'},
#        {'title': 'HttpRouteMatch',
#         'href': 'aws-properties-appmesh-route-httproutematch.html'},
#        {'title': 'HttpTimeout',
#         'href': 'aws-properties-appmesh-route-httptimeout.html'},
#        {'title': 'MatchRange',
#         'href': 'aws-properties-appmesh-route-matchrange.html'},
#        {'title': 'QueryParameter',
#         'href': 'aws-properties-appmesh-route-queryparameter.html'},
#        {'title': 'RouteSpec',
#         'href': 'aws-properties-appmesh-route-routespec.html'},
#        {'title': 'TcpRoute',
#         'href': 'aws-properties-appmesh-route-tcproute.html'},
#        {'title': 'TcpRouteAction',
#         'href': 'aws-properties-appmesh-route-tcprouteaction.html'},
#        {'title': 'TcpTimeout',
#         'href': 'aws-properties-appmesh-route-tcptimeout.html'},
#        {'title': 'WeightedTarget',
#         'href': 'aws-properties-appmesh-route-weightedtarget.html'}]},
#      {'title': 'AWS::AppMesh::VirtualGateway',
#       'href': 'aws-resource-appmesh-virtualgateway.html',
#       'contents': [{'title': 'SubjectAlternativeNameMatchers',
#         'href': 'aws-properties-appmesh-virtualgateway-subjectalternativenamematchers.html'},
#        {'title': 'SubjectAlternativeNames',
#         'href': 'aws-properties-appmesh-virtualgateway-subjectalternativenames.html'},
#        {'title': 'VirtualGatewayAccessLog',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayaccesslog.html'},
#        {'title': 'VirtualGatewayBackendDefaults',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaybackenddefaults.html'},
#        {'title': 'VirtualGatewayClientPolicy',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayclientpolicy.html'},
#        {'title': 'VirtualGatewayClientPolicyTls',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayclientpolicytls.html'},
#        {'title': 'VirtualGatewayClientTlsCertificate',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayclienttlscertificate.html'},
#        {'title': 'VirtualGatewayConnectionPool',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayconnectionpool.html'},
#        {'title': 'VirtualGatewayFileAccessLog',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayfileaccesslog.html'},
#        {'title': 'VirtualGatewayGrpcConnectionPool',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaygrpcconnectionpool.html'},
#        {'title': 'VirtualGatewayHealthCheckPolicy',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayhealthcheckpolicy.html'},
#        {'title': 'VirtualGatewayHttp2ConnectionPool',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayhttp2connectionpool.html'},
#        {'title': 'VirtualGatewayHttpConnectionPool',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayhttpconnectionpool.html'},
#        {'title': 'VirtualGatewayListener',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistener.html'},
#        {'title': 'VirtualGatewayListenerTls',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertls.html'},
#        {'title': 'VirtualGatewayListenerTlsAcmCertificate',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlsacmcertificate.html'},
#        {'title': 'VirtualGatewayListenerTlsCertificate',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlscertificate.html'},
#        {'title': 'VirtualGatewayListenerTlsFileCertificate',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlsfilecertificate.html'},
#        {'title': 'VirtualGatewayListenerTlsSdsCertificate',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlssdscertificate.html'},
#        {'title': 'VirtualGatewayListenerTlsValidationContext',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlsvalidationcontext.html'},
#        {'title': 'VirtualGatewayListenerTlsValidationContextTrust',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylistenertlsvalidationcontexttrust.html'},
#        {'title': 'VirtualGatewayLogging',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaylogging.html'},
#        {'title': 'VirtualGatewayPortMapping',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayportmapping.html'},
#        {'title': 'VirtualGatewaySpec',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewayspec.html'},
#        {'title': 'VirtualGatewayTlsValidationContext',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaytlsvalidationcontext.html'},
#        {'title': 'VirtualGatewayTlsValidationContextAcmTrust',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaytlsvalidationcontextacmtrust.html'},
#        {'title': 'VirtualGatewayTlsValidationContextFileTrust',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaytlsvalidationcontextfiletrust.html'},
#        {'title': 'VirtualGatewayTlsValidationContextSdsTrust',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaytlsvalidationcontextsdstrust.html'},
#        {'title': 'VirtualGatewayTlsValidationContextTrust',
#         'href': 'aws-properties-appmesh-virtualgateway-virtualgatewaytlsvalidationcontexttrust.html'}]},
#      {'title': 'AWS::AppMesh::VirtualNode',
#       'href': 'aws-resource-appmesh-virtualnode.html',
#       'contents': [{'title': 'AccessLog',
#         'href': 'aws-properties-appmesh-virtualnode-accesslog.html'},
#        {'title': 'AwsCloudMapInstanceAttribute',
#         'href': 'aws-properties-appmesh-virtualnode-awscloudmapinstanceattribute.html'},
#        {'title': 'AwsCloudMapServiceDiscovery',
#         'href': 'aws-properties-appmesh-virtualnode-awscloudmapservicediscovery.html'},
#        {'title': 'Backend',
#         'href': 'aws-properties-appmesh-virtualnode-backend.html'},
#        {'title': 'BackendDefaults',
#         'href': 'aws-properties-appmesh-virtualnode-backenddefaults.html'},
#        {'title': 'ClientPolicy',
#         'href': 'aws-properties-appmesh-virtualnode-clientpolicy.html'},
#        {'title': 'ClientPolicyTls',
#         'href': 'aws-properties-appmesh-virtualnode-clientpolicytls.html'},
#        {'title': 'ClientTlsCertificate',
#         'href': 'aws-properties-appmesh-virtualnode-clienttlscertificate.html'},
#        {'title': 'DnsServiceDiscovery',
#         'href': 'aws-properties-appmesh-virtualnode-dnsservicediscovery.html'},
#        {'title': 'Duration',
#         'href': 'aws-properties-appmesh-virtualnode-duration.html'},
#        {'title': 'FileAccessLog',
#         'href': 'aws-properties-appmesh-virtualnode-fileaccesslog.html'},
#        {'title': 'GrpcTimeout',
#         'href': 'aws-properties-appmesh-virtualnode-grpctimeout.html'},
#        {'title': 'HealthCheck',
#         'href': 'aws-properties-appmesh-virtualnode-healthcheck.html'},
#        {'title': 'HttpTimeout',
#         'href': 'aws-properties-appmesh-virtualnode-httptimeout.html'},
#        {'title': 'Listener',
#         'href': 'aws-properties-appmesh-virtualnode-listener.html'},
#        {'title': 'ListenerTimeout',
#         'href': 'aws-properties-appmesh-virtualnode-listenertimeout.html'},
#        {'title': 'ListenerTls',
#         'href': 'aws-properties-appmesh-virtualnode-listenertls.html'},
#        {'title': 'ListenerTlsAcmCertificate',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlsacmcertificate.html'},
#        {'title': 'ListenerTlsCertificate',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlscertificate.html'},
#        {'title': 'ListenerTlsFileCertificate',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlsfilecertificate.html'},
#        {'title': 'ListenerTlsSdsCertificate',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlssdscertificate.html'},
#        {'title': 'ListenerTlsValidationContext',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlsvalidationcontext.html'},
#        {'title': 'ListenerTlsValidationContextTrust',
#         'href': 'aws-properties-appmesh-virtualnode-listenertlsvalidationcontexttrust.html'},
#        {'title': 'Logging',
#         'href': 'aws-properties-appmesh-virtualnode-logging.html'},
#        {'title': 'OutlierDetection',
#         'href': 'aws-properties-appmesh-virtualnode-outlierdetection.html'},
#        {'title': 'PortMapping',
#         'href': 'aws-properties-appmesh-virtualnode-portmapping.html'},
#        {'title': 'ServiceDiscovery',
#         'href': 'aws-properties-appmesh-virtualnode-servicediscovery.html'},
#        {'title': 'SubjectAlternativeNameMatchers',
#         'href': 'aws-properties-appmesh-virtualnode-subjectalternativenamematchers.html'},
#        {'title': 'SubjectAlternativeNames',
#         'href': 'aws-properties-appmesh-virtualnode-subjectalternativenames.html'},
#        {'title': 'TcpTimeout',
#         'href': 'aws-properties-appmesh-virtualnode-tcptimeout.html'},
#        {'title': 'TlsValidationContext',
#         'href': 'aws-properties-appmesh-virtualnode-tlsvalidationcontext.html'},
#        {'title': 'TlsValidationContextAcmTrust',
#         'href': 'aws-properties-appmesh-virtualnode-tlsvalidationcontextacmtrust.html'},
#        {'title': 'TlsValidationContextFileTrust',
#         'href': 'aws-properties-appmesh-virtualnode-tlsvalidationcontextfiletrust.html'},
#        {'title': 'TlsValidationContextSdsTrust',
#         'href': 'aws-properties-appmesh-virtualnode-tlsvalidationcontextsdstrust.html'},
#        {'title': 'TlsValidationContextTrust',
#         'href': 'aws-properties-appmesh-virtualnode-tlsvalidationcontexttrust.html'},
#        {'title': 'VirtualNodeConnectionPool',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodeconnectionpool.html'},
#        {'title': 'VirtualNodeGrpcConnectionPool',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodegrpcconnectionpool.html'},
#        {'title': 'VirtualNodeHttp2ConnectionPool',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodehttp2connectionpool.html'},
#        {'title': 'VirtualNodeHttpConnectionPool',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodehttpconnectionpool.html'},
#        {'title': 'VirtualNodeSpec',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodespec.html'},
#        {'title': 'VirtualNodeTcpConnectionPool',
#         'href': 'aws-properties-appmesh-virtualnode-virtualnodetcpconnectionpool.html'},
#        {'title': 'VirtualServiceBackend',
#         'href': 'aws-properties-appmesh-virtualnode-virtualservicebackend.html'}]},
#      {'title': 'AWS::AppMesh::VirtualRouter',
#       'href': 'aws-resource-appmesh-virtualrouter.html',
#       'contents': [{'title': 'PortMapping',
#         'href': 'aws-properties-appmesh-virtualrouter-portmapping.html'},
#        {'title': 'VirtualRouterListener',
#         'href': 'aws-properties-appmesh-virtualrouter-virtualrouterlistener.html'},
#        {'title': 'VirtualRouterSpec',
#         'href': 'aws-properties-appmesh-virtualrouter-virtualrouterspec.html'}]},
#      {'title': 'AWS::AppMesh::VirtualService',
#       'href': 'aws-resource-appmesh-virtualservice.html',
#       'contents': [{'title': 'VirtualNodeServiceProvider',
#         'href': 'aws-properties-appmesh-virtualservice-virtualnodeserviceprovider.html'},
#        {'title': 'VirtualRouterServiceProvider',
#         'href': 'aws-properties-appmesh-virtualservice-virtualrouterserviceprovider.html'},
#        {'title': 'VirtualServiceProvider',
#         'href': 'aws-properties-appmesh-virtualservice-virtualserviceprovider.html'},
#        {'title': 'VirtualServiceSpec',
#         'href': 'aws-properties-appmesh-virtualservice-virtualservicespec.html'}]}]}]},
#  'AWS_AppRunner': {'contents': [{'title': 'App Runner',
#     'href': 'AWS_AppRunner.html',
#     'contents': [{'title': 'AWS::AppRunner::Service',
#       'href': 'aws-resource-apprunner-service.html',
#       'contents': [{'title': 'AuthenticationConfiguration',
#         'href': 'aws-properties-apprunner-service-authenticationconfiguration.html'},
#        {'title': 'CodeConfiguration',
#         'href': 'aws-properties-apprunner-service-codeconfiguration.html'},
#        {'title': 'CodeConfigurationValues',
#         'href': 'aws-properties-apprunner-service-codeconfigurationvalues.html'},
#        {'title': 'CodeRepository',
#         'href': 'aws-properties-apprunner-service-coderepository.html'},
#        {'title': 'EncryptionConfiguration',
#         'href': 'aws-properties-apprunner-service-encryptionconfiguration.html'},
#        {'title': 'HealthCheckConfiguration',
#         'href': 'aws-properties-apprunner-service-healthcheckconfiguration.html'},
#        {'title': 'ImageConfiguration',
#         'href': 'aws-properties-apprunner-service-imageconfiguration.html'},
#        {'title': 'ImageRepository',
#         'href': 'aws-properties-apprunner-service-imagerepository.html'},
#        {'title': 'InstanceConfiguration',
#         'href': 'aws-properties-apprunner-service-instanceconfiguration.html'},
#        {'title': 'KeyValuePair',
#         'href': 'aws-properties-apprunner-service-keyvaluepair.html'},
#        {'title': 'SourceCodeVersion',
#         'href': 'aws-properties-apprunner-service-sourcecodeversion.html'},
#        {'title': 'SourceConfiguration',
#         'href': 'aws-properties-apprunner-service-sourceconfiguration.html'}]}]}]},
#  'AWS_AppStream': {'contents': [{'title': 'AppStream 2.0',
#     'href': 'AWS_AppStream.html',
#     'contents': [{'title': 'AWS::AppStream::DirectoryConfig',
#       'href': 'aws-resource-appstream-directoryconfig.html',
#       'contents': [{'title': 'ServiceAccountCredentials',
#         'href': 'aws-properties-appstream-directoryconfig-serviceaccountcredentials.html'}]},
#      {'title': 'AWS::AppStream::Fleet',
#       'href': 'aws-resource-appstream-fleet.html',
#       'contents': [{'title': 'ComputeCapacity',
#         'href': 'aws-properties-appstream-fleet-computecapacity.html'},
#        {'title': 'DomainJoinInfo',
#         'href': 'aws-properties-appstream-fleet-domainjoininfo.html'},
#        {'title': 'VpcConfig',
#         'href': 'aws-properties-appstream-fleet-vpcconfig.html'}]},
#      {'title': 'AWS::AppStream::ImageBuilder',
#       'href': 'aws-resource-appstream-imagebuilder.html',
#       'contents': [{'title': 'AccessEndpoint',
#         'href': 'aws-properties-appstream-imagebuilder-accessendpoint.html'},
#        {'title': 'DomainJoinInfo',
#         'href': 'aws-properties-appstream-imagebuilder-domainjoininfo.html'},
#        {'title': 'VpcConfig',
#         'href': 'aws-properties-appstream-imagebuilder-vpcconfig.html'}]},
#      {'title': 'AWS::AppStream::Stack',
#       'href': 'aws-resource-appstream-stack.html',
#       'contents': [{'title': 'AccessEndpoint',
#         'href': 'aws-properties-appstream-stack-accessendpoint.html'},
#        {'title': 'ApplicationSettings',
#         'href': 'aws-properties-appstream-stack-applicationsettings.html'},
#        {'title': 'StorageConnector',
#         'href': 'aws-properties-appstream-stack-storageconnector.html'},
#        {'title': 'UserSetting',
#         'href': 'aws-properties-appstream-stack-usersetting.html'}]},
#      {'title': 'AWS::AppStream::StackFleetAssociation',
#       'href': 'aws-resource-appstream-stackfleetassociation.html'},
#      {'title': 'AWS::AppStream::StackUserAssociation',
#       'href': 'aws-resource-appstream-stackuserassociation.html'},
#      {'title': 'AWS::AppStream::User',
#       'href': 'aws-resource-appstream-user.html'}]}]},
#  'AWS_AppSync': {'contents': [{'title': 'AWS AppSync',
#     'href': 'AWS_AppSync.html',
#     'contents': [{'title': 'AWS::AppSync::ApiCache',
#       'href': 'aws-resource-appsync-apicache.html'},
#      {'title': 'AWS::AppSync::ApiKey',
#       'href': 'aws-resource-appsync-apikey.html'},
#      {'title': 'AWS::AppSync::DataSource',
#       'href': 'aws-resource-appsync-datasource.html',
#       'contents': [{'title': 'AuthorizationConfig',
#         'href': 'aws-properties-appsync-datasource-authorizationconfig.html'},
#        {'title': 'AwsIamConfig',
#         'href': 'aws-properties-appsync-datasource-awsiamconfig.html'},
#        {'title': 'DeltaSyncConfig',
#         'href': 'aws-properties-appsync-datasource-deltasyncconfig.html'},
#        {'title': 'DynamoDBConfig',
#         'href': 'aws-properties-appsync-datasource-dynamodbconfig.html'},
#        {'title': 'ElasticsearchConfig',
#         'href': 'aws-properties-appsync-datasource-elasticsearchconfig.html'},
# ...
#         'href': 'aws-properties-transfer-server-identityproviderdetails.html'},
#        {'title': 'Protocol',
#         'href': 'aws-properties-transfer-server-protocol.html'},
#        {'title': 'ProtocolDetails',
#         'href': 'aws-properties-transfer-server-protocoldetails.html'},
#        {'title': 'WorkflowDetail',
#         'href': 'aws-properties-transfer-server-workflowdetail.html'},
#        {'title': 'WorkflowDetails',
#         'href': 'aws-properties-transfer-server-workflowdetails.html'}]},
#      {'title': 'AWS::Transfer::User',
#       'href': 'aws-resource-transfer-user.html',
#       'contents': [{'title': 'HomeDirectoryMapEntry',
#         'href': 'aws-properties-transfer-user-homedirectorymapentry.html'},
#        {'title': 'PosixProfile',
#         'href': 'aws-properties-transfer-user-posixprofile.html'},
#        {'title': 'SshPublicKey',
#         'href': 'aws-properties-transfer-user-sshpublickey.html'}]}]}]},
#  'AWS_WAF': {'contents': [{'title': 'AWS WAF',
#     'href': 'AWS_WAF.html',
#     'contents': [{'title': 'AWS::WAF::ByteMatchSet',
#       'href': 'aws-resource-waf-bytematchset.html',
#       'contents': [{'title': 'ByteMatchTuple',
#         'href': 'aws-properties-waf-bytematchset-bytematchtuples.html'},
#        {'title': 'FieldToMatch',
#         'href': 'aws-properties-waf-bytematchset-bytematchtuples-fieldtomatch.html'}]},
#      {'title': 'AWS::WAF::IPSet',
#       'href': 'aws-resource-waf-ipset.html',
#       'contents': [{'title': 'IPSetDescriptor',
#         'href': 'aws-properties-waf-ipset-ipsetdescriptors.html'}]},
#      {'title': 'AWS::WAF::Rule',
#       'href': 'aws-resource-waf-rule.html',
#       'contents': [{'title': 'Predicate',
#         'href': 'aws-properties-waf-rule-predicates.html'}]},
#      {'title': 'AWS::WAF::SizeConstraintSet',
#       'href': 'aws-resource-waf-sizeconstraintset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-waf-sizeconstraintset-sizeconstraint-fieldtomatch.html'},
#        {'title': 'SizeConstraint',
#         'href': 'aws-properties-waf-sizeconstraintset-sizeconstraint.html'}]},
#      {'title': 'AWS::WAF::SqlInjectionMatchSet',
#       'href': 'aws-resource-waf-sqlinjectionmatchset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-waf-bytematchset-bytematchtuples-fieldtomatch-1.html'},
#        {'title': 'SqlInjectionMatchTuple',
#         'href': 'aws-properties-waf-sqlinjectionmatchset-sqlinjectionmatchtuples.html'}]},
#      {'title': 'AWS::WAF::WebACL',
#       'href': 'aws-resource-waf-webacl.html',
#       'contents': [{'title': 'ActivatedRule',
#         'href': 'aws-properties-waf-webacl-rules.html'},
#        {'title': 'WafAction',
#         'href': 'aws-properties-waf-webacl-action.html'}]},
#      {'title': 'AWS::WAF::XssMatchSet',
#       'href': 'aws-resource-waf-xssmatchset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-waf-xssmatchset-xssmatchtuple-fieldtomatch.html'},
#        {'title': 'XssMatchTuple',
#         'href': 'aws-properties-waf-xssmatchset-xssmatchtuple.html'}]}]}]},
#  'AWS_WAFRegional': {'contents': [{'title': 'AWS WAF Regional',
#     'href': 'AWS_WAFRegional.html',
#     'contents': [{'title': 'AWS::WAFRegional::ByteMatchSet',
#       'href': 'aws-resource-wafregional-bytematchset.html',
#       'contents': [{'title': 'ByteMatchTuple',
#         'href': 'aws-properties-wafregional-bytematchset-bytematchtuple.html'},
#        {'title': 'FieldToMatch',
#         'href': 'aws-properties-wafregional-bytematchset-fieldtomatch.html'}]},
#      {'title': 'AWS::WAFRegional::GeoMatchSet',
#       'href': 'aws-resource-wafregional-geomatchset.html',
#       'contents': [{'title': 'GeoMatchConstraint',
#         'href': 'aws-properties-wafregional-geomatchset-geomatchconstraint.html'}]},
#      {'title': 'AWS::WAFRegional::IPSet',
#       'href': 'aws-resource-wafregional-ipset.html',
#       'contents': [{'title': 'IPSetDescriptor',
#         'href': 'aws-properties-wafregional-ipset-ipsetdescriptor.html'}]},
#      {'title': 'AWS::WAFRegional::RateBasedRule',
#       'href': 'aws-resource-wafregional-ratebasedrule.html',
#       'contents': [{'title': 'Predicate',
#         'href': 'aws-properties-wafregional-ratebasedrule-predicate.html'}]},
#      {'title': 'AWS::WAFRegional::RegexPatternSet',
#       'href': 'aws-resource-wafregional-regexpatternset.html'},
#      {'title': 'AWS::WAFRegional::Rule',
#       'href': 'aws-resource-wafregional-rule.html',
#       'contents': [{'title': 'Predicate',
#         'href': 'aws-properties-wafregional-rule-predicate.html'}]},
#      {'title': 'AWS::WAFRegional::SizeConstraintSet',
#       'href': 'aws-resource-wafregional-sizeconstraintset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-wafregional-sizeconstraintset-fieldtomatch.html'},
#        {'title': 'SizeConstraint',
#         'href': 'aws-properties-wafregional-sizeconstraintset-sizeconstraint.html'}]},
#      {'title': 'AWS::WAFRegional::SqlInjectionMatchSet',
#       'href': 'aws-resource-wafregional-sqlinjectionmatchset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-wafregional-sqlinjectionmatchset-fieldtomatch.html'},
#        {'title': 'SqlInjectionMatchTuple',
#         'href': 'aws-properties-wafregional-sqlinjectionmatchset-sqlinjectionmatchtuple.html'}]},
#      {'title': 'AWS::WAFRegional::WebACL',
#       'href': 'aws-resource-wafregional-webacl.html',
#       'contents': [{'title': 'Action',
#         'href': 'aws-properties-wafregional-webacl-action.html'},
#        {'title': 'Rule',
#         'href': 'aws-properties-wafregional-webacl-rule.html'}]},
#      {'title': 'AWS::WAFRegional::WebACLAssociation',
#       'href': 'aws-resource-wafregional-webaclassociation.html'},
#      {'title': 'AWS::WAFRegional::XssMatchSet',
#       'href': 'aws-resource-wafregional-xssmatchset.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-wafregional-xssmatchset-fieldtomatch.html'},
#        {'title': 'XssMatchTuple',
#         'href': 'aws-properties-wafregional-xssmatchset-xssmatchtuple.html'}]}]}]},
#  'AWS_WAFv2': {'contents': [{'title': 'AWS WAF V2',
#     'href': 'AWS_WAFv2.html',
#     'contents': [{'title': 'AWS::WAFv2::IPSet',
#       'href': 'aws-resource-wafv2-ipset.html'},
#      {'title': 'AWS::WAFv2::LoggingConfiguration',
#       'href': 'aws-resource-wafv2-loggingconfiguration.html',
#       'contents': [{'title': 'FieldToMatch',
#         'href': 'aws-properties-wafv2-loggingconfiguration-fieldtomatch.html'}]},
#      {'title': 'AWS::WAFv2::RegexPatternSet',
#       'href': 'aws-resource-wafv2-regexpatternset.html'},
#      {'title': 'AWS::WAFv2::RuleGroup',
#       'href': 'aws-resource-wafv2-rulegroup.html',
#       'contents': [{'title': 'AndStatement',
#         'href': 'aws-properties-wafv2-rulegroup-andstatement.html'},
#        {'title': 'ByteMatchStatement',
#         'href': 'aws-properties-wafv2-rulegroup-bytematchstatement.html'},
#        {'title': 'CustomResponseBody',
#         'href': 'aws-properties-wafv2-rulegroup-customresponsebody.html'},
#        {'title': 'FieldToMatch',
#         'href': 'aws-properties-wafv2-rulegroup-fieldtomatch.html'},
#        {'title': 'ForwardedIPConfiguration',
#         'href': 'aws-properties-wafv2-rulegroup-forwardedipconfiguration.html'},
#        {'title': 'GeoMatchStatement',
#         'href': 'aws-properties-wafv2-rulegroup-geomatchstatement.html'},
#        {'title': 'IPSetForwardedIPConfiguration',
#         'href': 'aws-properties-wafv2-rulegroup-ipsetforwardedipconfiguration.html'},
#        {'title': 'IPSetReferenceStatement',
#         'href': 'aws-properties-wafv2-rulegroup-ipsetreferencestatement.html'},
#        {'title': 'JsonBody',
#         'href': 'aws-properties-wafv2-rulegroup-jsonbody.html'},
#        {'title': 'JsonMatchPattern',
#         'href': 'aws-properties-wafv2-rulegroup-jsonmatchpattern.html'},
#        {'title': 'Label', 'href': 'aws-properties-wafv2-rulegroup-label.html'},
#        {'title': 'LabelMatchStatement',
#         'href': 'aws-properties-wafv2-rulegroup-labelmatchstatement.html'},
#        {'title': 'LabelSummary',
#         'href': 'aws-properties-wafv2-rulegroup-labelsummary.html'},
#        {'title': 'NotStatement',
#         'href': 'aws-properties-wafv2-rulegroup-notstatement.html'},
#        {'title': 'OrStatement',
#         'href': 'aws-properties-wafv2-rulegroup-orstatement.html'},
#        {'title': 'RateBasedStatement',
#         'href': 'aws-properties-wafv2-rulegroup-ratebasedstatement.html'},
#        {'title': 'RegexPatternSetReferenceStatement',
#         'href': 'aws-properties-wafv2-rulegroup-regexpatternsetreferencestatement.html'},
#        {'title': 'Rule', 'href': 'aws-properties-wafv2-rulegroup-rule.html'},
#        {'title': 'RuleAction',
#         'href': 'aws-properties-wafv2-rulegroup-ruleaction.html'},
#        {'title': 'SizeConstraintStatement',
#         'href': 'aws-properties-wafv2-rulegroup-sizeconstraintstatement.html'},
#        {'title': 'SqliMatchStatement',
#         'href': 'aws-properties-wafv2-rulegroup-sqlimatchstatement.html'},
#        {'title': 'Statement',
#         'href': 'aws-properties-wafv2-rulegroup-statement.html'},
#        {'title': 'TextTransformation',
#         'href': 'aws-properties-wafv2-rulegroup-texttransformation.html'},
#        {'title': 'VisibilityConfig',
#         'href': 'aws-properties-wafv2-rulegroup-visibilityconfig.html'},
#        {'title': 'XssMatchStatement',
#         'href': 'aws-properties-wafv2-rulegroup-xssmatchstatement.html'}]},
#      {'title': 'AWS::WAFv2::WebACL',
#       'href': 'aws-resource-wafv2-webacl.html',
#       'contents': [{'title': 'AllowAction',
#         'href': 'aws-properties-wafv2-webacl-allowaction.html'},
#        {'title': 'AndStatement',
#         'href': 'aws-properties-wafv2-webacl-andstatement.html'},
#        {'title': 'BlockAction',
#         'href': 'aws-properties-wafv2-webacl-blockaction.html'},
#        {'title': 'ByteMatchStatement',
#         'href': 'aws-properties-wafv2-webacl-bytematchstatement.html'},
#        {'title': 'CountAction',
#         'href': 'aws-properties-wafv2-webacl-countaction.html'},
#        {'title': 'CustomHTTPHeader',
#         'href': 'aws-properties-wafv2-webacl-customhttpheader.html'},
#        {'title': 'CustomRequestHandling',
#         'href': 'aws-properties-wafv2-webacl-customrequesthandling.html'},
#        {'title': 'CustomResponse',
#         'href': 'aws-properties-wafv2-webacl-customresponse.html'},
#        {'title': 'CustomResponseBody',
#         'href': 'aws-properties-wafv2-webacl-customresponsebody.html'},
#        {'title': 'DefaultAction',
#         'href': 'aws-properties-wafv2-webacl-defaultaction.html'},
#        {'title': 'ExcludedRule',
#         'href': 'aws-properties-wafv2-webacl-excludedrule.html'},
#        {'title': 'FieldToMatch',
#         'href': 'aws-properties-wafv2-webacl-fieldtomatch.html'},
#        {'title': 'ForwardedIPConfiguration',
#         'href': 'aws-properties-wafv2-webacl-forwardedipconfiguration.html'},
#        {'title': 'GeoMatchStatement',
#         'href': 'aws-properties-wafv2-webacl-geomatchstatement.html'},
#        {'title': 'IPSetForwardedIPConfiguration',
#         'href': 'aws-properties-wafv2-webacl-ipsetforwardedipconfiguration.html'},
#        {'title': 'IPSetReferenceStatement',
#         'href': 'aws-properties-wafv2-webacl-ipsetreferencestatement.html'},
#        {'title': 'JsonBody',
#         'href': 'aws-properties-wafv2-webacl-jsonbody.html'},
#        {'title': 'JsonMatchPattern',
#         'href': 'aws-properties-wafv2-webacl-jsonmatchpattern.html'},
#        {'title': 'Label', 'href': 'aws-properties-wafv2-webacl-label.html'},
#        {'title': 'LabelMatchStatement',
#         'href': 'aws-properties-wafv2-webacl-labelmatchstatement.html'},
#        {'title': 'ManagedRuleGroupStatement',
#         'href': 'aws-properties-wafv2-webacl-managedrulegroupstatement.html'},
#        {'title': 'NotStatement',
#         'href': 'aws-properties-wafv2-webacl-notstatement.html'},
#        {'title': 'OrStatement',
#         'href': 'aws-properties-wafv2-webacl-orstatement.html'},
#        {'title': 'OverrideAction',
#         'href': 'aws-properties-wafv2-webacl-overrideaction.html'},
#        {'title': 'RateBasedStatement',
#         'href': 'aws-properties-wafv2-webacl-ratebasedstatement.html'},
#        {'title': 'RegexPatternSetReferenceStatement',
#         'href': 'aws-properties-wafv2-webacl-regexpatternsetreferencestatement.html'},
#        {'title': 'Rule', 'href': 'aws-properties-wafv2-webacl-rule.html'},
#        {'title': 'RuleAction',
#         'href': 'aws-properties-wafv2-webacl-ruleaction.html'},
#        {'title': 'RuleGroupReferenceStatement',
#         'href': 'aws-properties-wafv2-webacl-rulegroupreferencestatement.html'},
#        {'title': 'SizeConstraintStatement',
#         'href': 'aws-properties-wafv2-webacl-sizeconstraintstatement.html'},
#        {'title': 'SqliMatchStatement',
#         'href': 'aws-properties-wafv2-webacl-sqlimatchstatement.html'},
#        {'title': 'Statement',
#         'href': 'aws-properties-wafv2-webacl-statement.html'},
#        {'title': 'TextTransformation',
#         'href': 'aws-properties-wafv2-webacl-texttransformation.html'},
#        {'title': 'VisibilityConfig',
#         'href': 'aws-properties-wafv2-webacl-visibilityconfig.html'},
#        {'title': 'XssMatchStatement',
#         'href': 'aws-properties-wafv2-webacl-xssmatchstatement.html'}]},
#      {'title': 'AWS::WAFv2::WebACLAssociation',
#       'href': 'aws-resource-wafv2-webaclassociation.html'}]}]},
#  'AWS_Wisdom': {'contents': [{'title': 'Wisdom',
#     'href': 'AWS_Wisdom.html',
#     'contents': [{'title': 'AWS::Wisdom::Assistant',
#       'href': 'aws-resource-wisdom-assistant.html',
#       'contents': [{'title': 'ServerSideEncryptionConfiguration',
#         'href': 'aws-properties-wisdom-assistant-serversideencryptionconfiguration.html'}]},
#      {'title': 'AWS::Wisdom::AssistantAssociation',
#       'href': 'aws-resource-wisdom-assistantassociation.html',
#       'contents': [{'title': 'AssociationData',
#         'href': 'aws-properties-wisdom-assistantassociation-associationdata.html'}]},
#      {'title': 'AWS::Wisdom::KnowledgeBase',
#       'href': 'aws-resource-wisdom-knowledgebase.html',
#       'contents': [{'title': 'AppIntegrationsConfiguration',
#         'href': 'aws-properties-wisdom-knowledgebase-appintegrationsconfiguration.html'},
#        {'title': 'RenderingConfiguration',
#         'href': 'aws-properties-wisdom-knowledgebase-renderingconfiguration.html'},
#        {'title': 'ServerSideEncryptionConfiguration',
#         'href': 'aws-properties-wisdom-knowledgebase-serversideencryptionconfiguration.html'},
#        {'title': 'SourceConfiguration',
#         'href': 'aws-properties-wisdom-knowledgebase-sourceconfiguration.html'}]}]}]},
#  'AWS_WorkSpaces': {'contents': [{'title': 'WorkSpaces',
#     'href': 'AWS_WorkSpaces.html',
#     'contents': [{'title': 'AWS::WorkSpaces::ConnectionAlias',
#       'href': 'aws-resource-workspaces-connectionalias.html',
#       'contents': [{'title': 'ConnectionAliasAssociation',
#         'href': 'aws-properties-workspaces-connectionalias-connectionaliasassociation.html'}]},
#      {'title': 'AWS::WorkSpaces::Workspace',
#       'href': 'aws-resource-workspaces-workspace.html',
#       'contents': [{'title': 'WorkspaceProperties',
#         'href': 'aws-properties-workspaces-workspace-workspaceproperties.html'}]}]}]},
#  'AWS_XRay': {'contents': [{'title': 'X-Ray',
#     'href': 'AWS_XRay.html',
#     'contents': [{'title': 'AWS::XRay::Group',
#       'href': 'aws-resource-xray-group.html',
#       'contents': [{'title': 'InsightsConfiguration',
#         'href': 'aws-properties-xray-group-insightsconfiguration.html'}]},
#      {'title': 'AWS::XRay::SamplingRule',
#       'href': 'aws-resource-xray-samplingrule.html',
#       'contents': [{'title': 'SamplingRule',
#         'href': 'aws-properties-xray-samplingrule-samplingrule.html'},
#        {'title': 'SamplingRuleRecord',
#         'href': 'aws-properties-xray-samplingrule-samplingrulerecord.html'},
#        {'title': 'SamplingRuleUpdate',
#         'href': 'aws-properties-xray-samplingrule-samplingruleupdate.html'}]}]}]}}

# %%
dump_json("dumps/aws_cf_resources_docs.json", aws_cloud_formation_resource_docs)

# %%
dump_json("dumps/aws_cf_resources.json", aws_cloud_formation_resources)

# %% [markdown]
# ---
#
# ## AWS Service Authorization Reference

# %%
AWS_SERVICE_AUTHZ_LIST_URL = "https://docs.aws.amazon.com/service-authorization/latest/reference/reference_policies_actions-resources-contextkeys.html"
AWS_REFERENCES_ROOT_URL = "https://docs.aws.amazon.com/service-authorization/latest/reference/"

# %%
service_list_body = requests.get(AWS_SERVICE_AUTHZ_LIST_URL).text

# %%
services_soup = BeautifulSoup(service_list_body, "html.parser")
service_list_dom = etree.HTML(str(services_soup))

# %%
services_links = {}

for link in service_list_dom.xpath('//*[@class="highlights"]/ul/li/a'):
    services_links[link.text] = urllib.parse.urljoin(AWS_REFERENCES_ROOT_URL, link.get("href"))
    
len(services_links.keys())
# Out:
# 299

# %%
def parse_service_action(url: str):
    body = requests.get(url).text
    soup = BeautifulSoup(body, "html.parser")
    dom = etree.HTML(str(soup))
    actions = []
    prefix = None
    try:
        service_prefix = dom.xpath('//*[@id="main-col-body"]/p[1]/code')[0]
        prefix = service_prefix.text
    except IndexError:
        prefix = url
    
    for i in range(3,6):
        tables = dom.xpath(f'//*[@id="main-col-body"]/div[{i}]/div/table')
        if len(tables):
            table = tables[0]
            break
    
    rows = table.findall("tr")
    for tr in rows:
        
        tds = tr.findall("td")
        if len(tds) < 5:
            continue
        
        action_td, description_td, *_ = tds
        
        try:
            action_text = action_td.text.strip()
            if len(action_td.text) < 3:
                _, action_link, *_ = action_td.findall("a")
                action_text = action_link.text.strip()
        except (ValueError, AttributeError):
            # individual actions are not critical for my use case.
            # Needs to be tuned in order to have 100% accuracy.
            continue
        
        try:
            tmp = {}
            tmp[action_text] = re.sub(r"\s+", " ", description_td.text.strip().replace("\n", " "))
            actions.append(tmp)
        except AttributeError:
            continue
        
    return prefix, actions
            
# parse_service_action(services_links["Amazon EC2"])

# %%
aws_service_authz_mapping = []

for service_name, service_link in  services_links.items():
    print(service_name)
    prefix, actions = parse_service_action(service_link)
    
    aws_service_authz_mapping.append({
        "name": service_name,
        "prefix": prefix,
        "docs": service_link,
        "actions": actions,
    })
# Out:
# AWS Account Management
# AWS Activate
# Alexa for Business
# AmazonMediaImport
# AWS Amplify
# AWS Amplify Admin
# Apache Kafka APIs for Amazon MSK clusters
# Amazon API Gateway
# Amazon API Gateway Management
# Amazon API Gateway Management V2
# AWS App Mesh
# AWS App Mesh Preview
# AWS App Runner
# AWS AppConfig
# Amazon AppFlow
# Amazon AppIntegrations
# Application Auto Scaling
# AWS Application Cost Profiler Service
# Application Discovery
# Application Discovery Arsenal
# AWS Application Migration Service
# Amazon AppStream 2.0
# AWS AppSync
# AWS Artifact
# Amazon Athena
# AWS Audit Manager
# AWS Auto Scaling
# AWSDataSync
# AWS Backup
# AWS Backup storage
# AWS Batch
# AWS Billing and Cost Management
# Amazon Braket
# AWS Budget Service
# AWS BugBust
# AWS Certificate Manager
# AWS Certificate Manager Private Certificate Authority
# AWS Chatbot
# Amazon Chime
# AWS Cloud Control API
# Amazon Cloud Directory
# AWS Cloud Map
# AWS Cloud9
# AWS CloudFormation
# Amazon CloudFront
# AWS CloudHSM
# Amazon CloudSearch
# AWS CloudShell
# AWS CloudTrail
# Amazon CloudWatch
# CloudWatch Application Insights
# Amazon CloudWatch Logs
# Amazon CloudWatch Synthetics
# AWS CodeArtifact
# AWS CodeBuild
# AWS CodeCommit
# AWS CodeDeploy
# Amazon CodeGuru
# Amazon CodeGuru Profiler
# Amazon CodeGuru Reviewer
# AWS CodePipeline
# AWS CodeStar
# AWS CodeStar Connections
# AWS CodeStar Notifications
# Amazon Cognito Identity
# Amazon Cognito Sync
# Amazon Cognito User Pools
# Amazon Comprehend
# Amazon Comprehend Medical
# AWS Compute Optimizer
# AWS Config
# Amazon Connect
# Amazon Connect Customer Profiles
# Amazon Connect Voice ID
# Amazon Connect Wisdom
# AWS Connector Service
# AWS Control Tower
# AWS Cost and Usage Report
# AWS Cost Explorer Service
# AWS Data Exchange
# Amazon Data Lifecycle Manager
# Data Pipeline
# AWS Database Migration Service
# Database Query Metadata Service
# AWS DeepComposer
# AWS DeepLens
# AWS DeepRacer
# Amazon Detective
# AWS Device Farm
# Amazon DevOps Guru
# AWS Direct Connect
# AWS Directory Service
# Amazon DynamoDB
# Amazon DynamoDB Accelerator (DAX)
# Amazon EC2
# Amazon EC2 Auto Scaling
# Amazon EC2 Image Builder
# Amazon EC2 Instance Connect
# AWS Elastic Beanstalk
# Amazon Elastic Block Store
# Amazon Elastic Container Registry
# Amazon Elastic Container Registry Public
# Amazon Elastic Container Service
# Amazon Elastic File System
# Amazon Elastic Inference
# Amazon Elastic Kubernetes Service
# Elastic Load Balancing
# Elastic Load Balancing V2
# Amazon Elastic MapReduce
# Amazon Elastic Transcoder
# Amazon ElastiCache
# AWS Elemental Appliances and Software
# AWS Elemental Appliances and Software Activation Service
# AWS Elemental MediaConnect
# AWS Elemental MediaConvert
# AWS Elemental MediaLive
# AWS Elemental MediaPackage
# AWS Elemental MediaPackage VOD
# AWS Elemental MediaStore
# AWS Elemental MediaTailor
# Elemental Support Cases
# Elemental Support Content
# Amazon EMR on EKS (EMR Containers)
# Amazon EventBridge
# Amazon EventBridge Schemas
# AWS Fault Injection Simulator
# Amazon FinSpace
# AWS Firewall Manager
# Amazon Forecast
# Amazon Fraud Detector
# Amazon FreeRTOS
# Amazon FSx
# Amazon GameLift
# Amazon Glacier
# AWS Global Accelerator
# AWS Glue
# AWS Glue DataBrew
# AWS Ground Station
# Amazon GroundTruth Labeling
# Amazon GuardDuty
# AWS Health APIs and Notifications
# Amazon HealthLake
# High-volume outbound communications
# Amazon Honeycode
# AWS IAM Access Analyzer
# Identity And Access Management
# AWS Identity Store
# AWS Import Export Disk Service
# Amazon Inspector
# Amazon Interactive Video Service
# AWS IoT
# AWS IoT 1-Click
# AWS IoT Analytics
# AWS IoT Core Device Advisor
# AWS IoT Core for LoRaWAN
# AWS IoT Device Tester
# AWS IoT Events
# AWS IoT Fleet Hub for Device Management
# AWS IoT Greengrass
# AWS IoT Greengrass V2
# AWS IoT SiteWise
# AWS IoT Things Graph
# AWS IQ
# AWS IQ Permissions
# Amazon Kendra
# AWS Key Management Service
# Amazon Keyspaces (for Apache Cassandra)
# Amazon Kinesis
# Amazon Kinesis Analytics
# Amazon Kinesis Analytics V2
# Amazon Kinesis Firehose
# Amazon Kinesis Video Streams
# AWS Lake Formation
# AWS Lambda
# Launch Wizard
# Amazon Lex
# Amazon Lex V2
# AWS License Manager
# Amazon Lightsail
# Amazon Location
# Amazon Lookout for Equipment
# Amazon Lookout for Metrics
# Amazon Lookout for Vision
# Amazon Machine Learning
# Amazon Macie
# Amazon Macie Classic
# Amazon Managed Blockchain
# Amazon Managed Grafana
# Amazon Managed Service for Prometheus
# Amazon Managed Streaming for Apache Kafka
# Amazon Managed Streaming for Kafka Connect
# Amazon Managed Workflows for Apache Airflow
# AWS Marketplace
# AWS Marketplace Catalog
# AWS Marketplace Commerce Analytics Service
# AWS Marketplace Entitlement Service
# AWS Marketplace Image Building Service
# AWS Marketplace Management Portal
# AWS Marketplace Metering Service
# AWS Marketplace Private Marketplace
# AWS Marketplace Procurement Systems Integration
# Amazon Mechanical Turk
# Amazon MemoryDB
# Amazon Message Delivery Service
# AWS Migration Hub
# AWS Migration Hub Strategy Recommendations.
# Amazon Mobile Analytics
# AWS Mobile Hub
# Amazon Monitron
# Amazon MQ
# Amazon Neptune
# AWS Network Firewall
# Network Manager
# Amazon Nimble Studio
# Amazon OpenSearch Service (successor to Amazon Elasticsearch Service)
# AWS OpsWorks
# AWS OpsWorks Configuration Management
# AWS Organizations
# AWS Outposts
# AWS Panorama
# AWS Performance Insights
# Amazon Personalize
# Amazon Pinpoint
# Amazon Pinpoint Email Service
# Amazon Pinpoint SMS and Voice Service
# Amazon Polly
# AWS Price List
# AWS Proton
# AWS Purchase Orders Console
# Amazon QLDB
# Amazon QuickSight
# Amazon RDS
# Amazon RDS Data API
# Amazon RDS IAM Authentication
# Amazon Redshift
# Amazon Redshift Data API
# Amazon Rekognition
# AWS Resource Access Manager
# Amazon Resource Group Tagging API
# AWS Resource Groups
# AWS RoboMaker
# Amazon Route 53
# Amazon Route 53 Domains
# Amazon Route 53 Recovery Cluster
# Amazon Route 53 Recovery Controls
# Amazon Route 53 Recovery Readiness
# Amazon Route 53 Resolver
# Amazon S3
# Amazon S3 Object Lambda
# Amazon S3 on Outposts
# Amazon SageMaker
# AWS Savings Plans
# AWS Secrets Manager
# AWS Security Hub
# AWS Security Token Service
# AWS Server Migration Service
# AWS Serverless Application Repository
# AWS Service Catalog
# AWS Service Quotas
# Amazon SES
# Amazon Session Manager Message Gateway Service
# AWS Shield
# AWS Signer
# Amazon Simple Email Service v2
# Amazon Simple Workflow Service
# Amazon SimpleDB
# AWS Snow Device Management
# AWS Snowball
# Amazon SNS
# AWS SQL Workbench
# Amazon SQS
# AWS SSO
# AWS SSO Directory
# AWS Step Functions
# Amazon Storage Gateway
# Amazon Sumerian
# AWS Support
# AWS Systems Manager
# AWS Systems Manager Incident Manager
# AWS Systems Manager Incident Manager Contacts
# AWS Tag Editor
# Amazon Textract
# Amazon Timestream
# AWS Tiros
# Amazon Transcribe
# AWS Transfer Family
# Amazon Translate
# AWS Trusted Advisor
# AWS WAF
# AWS WAF Regional
# AWS WAF V2
# AWS Well-Architected Tool
# Amazon WorkDocs
# Amazon WorkLink
# Amazon WorkMail
# Amazon WorkMail Message Flow
# Amazon WorkSpaces
# Amazon WorkSpaces Application Manager
# AWS X-Ray

# %%
dump_json("dumps/aws_actions_reference.json", aws_service_authz_mapping)

# %%
def name_to_prefix(out, item):
    out[item["name"]] = item["prefix"]
    return out
    
action_name_to_prefix_mapping = functools.reduce(name_to_prefix, aws_service_authz_mapping, {})
action_name_to_prefix_mapping
# Out:
# {'AWS Account Management': 'account',
#  'AWS Activate': 'activate',
#  'Alexa for Business': 'a4b',
#  'AmazonMediaImport': 'mediaimport',
#  'AWS Amplify': 'amplify',
#  'AWS Amplify Admin': 'amplifybackend',
#  'Apache Kafka APIs for Amazon MSK clusters': 'kafka-cluster',
#  'Amazon API Gateway': 'execute-api',
#  'Amazon API Gateway Management': 'apigateway',
#  'Amazon API Gateway Management V2': 'apigateway',
#  'AWS App Mesh': 'appmesh',
#  'AWS App Mesh Preview': 'appmesh-preview',
#  'AWS App Runner': 'apprunner',
#  'AWS AppConfig': 'appconfig',
#  'Amazon AppFlow': 'appflow',
#  'Amazon AppIntegrations': 'app-integrations',
#  'Application Auto Scaling': 'application-autoscaling',
#  'AWS Application Cost Profiler Service': 'application-cost-profiler',
#  'Application Discovery': 'discovery',
#  'Application Discovery Arsenal': 'arsenal',
#  'AWS Application Migration Service': 'mgn',
#  'Amazon AppStream 2.0': 'appstream',
#  'AWS AppSync': 'appsync',
#  'AWS Artifact': 'artifact',
#  'Amazon Athena': 'athena',
#  'AWS Audit Manager': 'auditmanager',
#  'AWS Auto Scaling': 'autoscaling-plans',
#  'AWSDataSync': 'datasync',
#  'AWS Backup': 'backup',
#  'AWS Backup storage': 'backup-storage',
#  'AWS Batch': 'batch',
#  'AWS Billing and Cost Management': 'aws-portal',
#  'Amazon Braket': 'braket',
#  'AWS Budget Service': 'budgets',
#  'AWS BugBust': 'bugbust',
#  'AWS Certificate Manager': 'acm',
#  'AWS Certificate Manager Private Certificate Authority': 'acm-pca',
#  'AWS Chatbot': 'chatbot',
#  'Amazon Chime': 'chime',
#  'AWS Cloud Control API': 'cloudformation',
#  'Amazon Cloud Directory': 'clouddirectory',
#  'AWS Cloud Map': 'servicediscovery',
#  'AWS Cloud9': 'cloud9',
#  'AWS CloudFormation': 'cloudformation',
#  'Amazon CloudFront': 'cloudfront',
#  'AWS CloudHSM': 'cloudhsm',
#  'Amazon CloudSearch': 'cloudsearch',
#  'AWS CloudShell': 'cloudshell',
#  'AWS CloudTrail': 'cloudtrail',
#  'Amazon CloudWatch': 'cloudwatch',
#  'CloudWatch Application Insights': 'applicationinsights',
#  'Amazon CloudWatch Logs': 'logs',
#  'Amazon CloudWatch Synthetics': 'synthetics',
#  'AWS CodeArtifact': 'codeartifact',
#  'AWS CodeBuild': 'codebuild',
#  'AWS CodeCommit': 'codecommit',
#  'AWS CodeDeploy': 'codedeploy',
#  'Amazon CodeGuru': 'codeguru',
#  'Amazon CodeGuru Profiler': 'codeguru-profiler',
#  'Amazon CodeGuru Reviewer': 'codeguru-reviewer',
#  'AWS CodePipeline': 'codepipeline',
#  'AWS CodeStar': 'codestar',
#  'AWS CodeStar Connections': 'codestar-connections',
#  'AWS CodeStar Notifications': 'codestar-notifications',
#  'Amazon Cognito Identity': 'cognito-identity',
#  'Amazon Cognito Sync': 'cognito-sync',
#  'Amazon Cognito User Pools': 'cognito-idp',
#  'Amazon Comprehend': 'comprehend',
#  'Amazon Comprehend Medical': 'comprehendmedical',
#  'AWS Compute Optimizer': 'compute-optimizer',
#  'AWS Config': 'config',
#  'Amazon Connect': 'connect',
#  'Amazon Connect Customer Profiles': 'profile',
#  'Amazon Connect Voice ID': 'voiceid',
#  'Amazon Connect Wisdom': 'wisdom',
#  'AWS Connector Service': 'awsconnector',
#  'AWS Control Tower': 'controltower',
#  'AWS Cost and Usage Report': 'cur',
#  'AWS Cost Explorer Service': 'ce',
#  'AWS Data Exchange': 'dataexchange',
#  'Amazon Data Lifecycle Manager': 'dlm',
#  'Data Pipeline': 'datapipeline',
#  'AWS Database Migration Service': 'dms',
#  'Database Query Metadata Service': 'dbqms',
#  'AWS DeepComposer': 'deepcomposer',
#  'AWS DeepLens': 'deeplens',
#  'AWS DeepRacer': 'deepracer',
#  'Amazon Detective': 'detective',
#  'AWS Device Farm': 'devicefarm',
#  'Amazon DevOps Guru': 'devops-guru',
#  'AWS Direct Connect': 'directconnect',
#  'AWS Directory Service': 'ds',
#  'Amazon DynamoDB': 'dynamodb',
#  'Amazon DynamoDB Accelerator (DAX)': 'dax',
#  'Amazon EC2': 'ec2',
#  'Amazon EC2 Auto Scaling': 'autoscaling',
#  'Amazon EC2 Image Builder': 'imagebuilder',
#  'Amazon EC2 Instance Connect': 'ec2-instance-connect',
#  'AWS Elastic Beanstalk': 'elasticbeanstalk',
#  'Amazon Elastic Block Store': 'ebs',
#  'Amazon Elastic Container Registry': 'ecr',
#  'Amazon Elastic Container Registry Public': 'ecr-public',
#  'Amazon Elastic Container Service': 'ecs',
#  'Amazon Elastic File System': 'elasticfilesystem',
#  'Amazon Elastic Inference': 'elastic-inference',
#  'Amazon Elastic Kubernetes Service': 'eks',
#  'Elastic Load Balancing': 'elasticloadbalancing',
#  'Elastic Load Balancing V2': 'elasticloadbalancing',
#  'Amazon Elastic MapReduce': 'elasticmapreduce',
#  'Amazon Elastic Transcoder': 'elastictranscoder',
#  'Amazon ElastiCache': 'elasticache',
#  'AWS Elemental Appliances and Software': 'elemental-appliances-software',
#  'AWS Elemental Appliances and Software Activation Service': 'elemental-activations',
#  'AWS Elemental MediaConnect': 'mediaconnect',
#  'AWS Elemental MediaConvert': 'mediaconvert',
#  'AWS Elemental MediaLive': 'medialive',
#  'AWS Elemental MediaPackage': 'mediapackage',
#  'AWS Elemental MediaPackage VOD': 'mediapackage-vod',
#  'AWS Elemental MediaStore': 'mediastore',
#  'AWS Elemental MediaTailor': 'mediatailor',
#  'Elemental Support Cases': 'elemental-support-cases',
#  'Elemental Support Content': 'elemental-support-content',
#  'Amazon EMR on EKS (EMR Containers)': 'emr-containers',
#  'Amazon EventBridge': 'events',
#  'Amazon EventBridge Schemas': 'schemas',
#  'AWS Fault Injection Simulator': 'fis',
#  'Amazon FinSpace': 'finspace',
#  'AWS Firewall Manager': 'fms',
#  'Amazon Forecast': 'forecast',
#  'Amazon Fraud Detector': 'frauddetector',
#  'Amazon FreeRTOS': 'freertos',
#  'Amazon FSx': 'fsx',
#  'Amazon GameLift': 'gamelift',
#  'Amazon Glacier': 'glacier',
#  'AWS Global Accelerator': 'globalaccelerator',
#  'AWS Glue': 'glue',
#  'AWS Glue DataBrew': 'databrew',
#  'AWS Ground Station': 'groundstation',
#  'Amazon GroundTruth Labeling': 'groundtruthlabeling',
#  'Amazon GuardDuty': 'guardduty',
#  'AWS Health APIs and Notifications': 'health',
#  'Amazon HealthLake': 'healthlake',
#  'High-volume outbound communications': 'connect-campaigns',
#  'Amazon Honeycode': 'honeycode',
#  'AWS IAM Access Analyzer': 'access-analyzer',
#  'Identity And Access Management': 'iam',
#  'AWS Identity Store': 'identitystore',
#  'AWS Import Export Disk Service': 'importexport',
#  'Amazon Inspector': 'inspector',
#  'Amazon Interactive Video Service': 'ivs',
#  'AWS IoT': 'iot',
#  'AWS IoT 1-Click': 'iot1click',
#  'AWS IoT Analytics': 'iotanalytics',
#  'AWS IoT Core Device Advisor': 'iotdeviceadvisor',
#  'AWS IoT Core for LoRaWAN': 'iotwireless',
#  'AWS IoT Device Tester': 'iot-device-tester',
#  'AWS IoT Events': 'iotevents',
#  'AWS IoT Fleet Hub for Device Management': 'iotfleethub',
#  'AWS IoT Greengrass': 'greengrass',
#  'AWS IoT Greengrass V2': 'greengrass',
#  'AWS IoT SiteWise': 'iotsitewise',
#  'AWS IoT Things Graph': 'iotthingsgraph',
#  'AWS IQ': 'iq',
#  'AWS IQ Permissions': 'iq-permission',
#  'Amazon Kendra': 'kendra',
#  'AWS Key Management Service': 'kms',
#  'Amazon Keyspaces (for Apache Cassandra)': 'cassandra',
#  'Amazon Kinesis': 'kinesis',
#  'Amazon Kinesis Analytics': 'kinesisanalytics',
#  'Amazon Kinesis Analytics V2': 'kinesisanalytics',
#  'Amazon Kinesis Firehose': 'firehose',
#  'Amazon Kinesis Video Streams': 'kinesisvideo',
#  'AWS Lake Formation': 'lakeformation',
#  'AWS Lambda': 'lambda',
#  'Launch Wizard': 'launchwizard',
#  'Amazon Lex': 'lex',
#  'Amazon Lex V2': 'lex',
#  'AWS License Manager': 'license-manager',
#  'Amazon Lightsail': 'lightsail',
#  'Amazon Location': 'geo',
#  'Amazon Lookout for Equipment': 'lookoutequipment',
#  'Amazon Lookout for Metrics': 'lookoutmetrics',
#  'Amazon Lookout for Vision': 'lookoutvision',
#  'Amazon Machine Learning': 'machinelearning',
#  'Amazon Macie': 'macie2',
#  'Amazon Macie Classic': 'macie',
#  'Amazon Managed Blockchain': 'managedblockchain',
#  'Amazon Managed Grafana': 'grafana',
#  'Amazon Managed Service for Prometheus': 'aps',
#  'Amazon Managed Streaming for Apache Kafka': 'kafka',
#  'Amazon Managed Streaming for Kafka Connect': 'kafkaconnect',
#  'Amazon Managed Workflows for Apache Airflow': 'airflow',
#  'AWS Marketplace': 'aws-marketplace',
#  'AWS Marketplace Catalog': 'aws-marketplace',
#  'AWS Marketplace Commerce Analytics Service': 'marketplacecommerceanalytics',
#  'AWS Marketplace Entitlement Service': 'aws-marketplace',
#  'AWS Marketplace Image Building Service': 'aws-marketplace',
#  'AWS Marketplace Management Portal': 'aws-marketplace-management',
#  'AWS Marketplace Metering Service': 'aws-marketplace',
#  'AWS Marketplace Private Marketplace': 'aws-marketplace',
#  'AWS Marketplace Procurement Systems Integration': 'aws-marketplace',
#  'Amazon Mechanical Turk': 'mechanicalturk',
#  'Amazon MemoryDB': 'memorydb',
#  'Amazon Message Delivery Service': 'ec2messages',
#  'AWS Migration Hub': 'mgh',
#  'AWS Migration Hub Strategy Recommendations.': 'migrationhub-strategy',
#  'Amazon Mobile Analytics': 'mobileanalytics',
#  'AWS Mobile Hub': 'mobilehub',
#  'Amazon Monitron': 'monitron',
#  'Amazon MQ': 'mq',
#  'Amazon Neptune': 'neptune-db',
#  'AWS Network Firewall': 'network-firewall',
#  'Network Manager': 'networkmanager',
#  'Amazon Nimble Studio': 'nimble',
#  'Amazon OpenSearch Service (successor to Amazon Elasticsearch Service)': 'es',
#  'AWS OpsWorks': 'opsworks',
#  'AWS OpsWorks Configuration Management': 'opsworks-cm',
#  'AWS Organizations': 'organizations',
#  'AWS Outposts': 'outposts',
#  'AWS Panorama': 'panorama',
#  'AWS Performance Insights': 'pi',
#  'Amazon Personalize': 'personalize',
#  'Amazon Pinpoint': 'mobiletargeting',
#  'Amazon Pinpoint Email Service': 'ses',
#  'Amazon Pinpoint SMS and Voice Service': 'sms-voice',
#  'Amazon Polly': 'polly',
#  'AWS Price List': 'pricing',
#  'AWS Proton': 'proton',
#  'AWS Purchase Orders Console': 'purchase-orders',
#  'Amazon QLDB': 'qldb',
#  'Amazon QuickSight': 'quicksight',
#  'Amazon RDS': 'rds',
#  'Amazon RDS Data API': 'rds-data',
#  'Amazon RDS IAM Authentication': 'rds-db',
#  'Amazon Redshift': 'redshift',
#  'Amazon Redshift Data API': 'redshift-data',
#  'Amazon Rekognition': 'rekognition',
#  'AWS Resource Access Manager': 'ram',
#  'Amazon Resource Group Tagging API': 'tag',
#  'AWS Resource Groups': 'resource-groups',
#  'AWS RoboMaker': 'robomaker',
#  'Amazon Route 53': 'route53',
#  'Amazon Route 53 Domains': 'route53domains',
#  'Amazon Route 53 Recovery Cluster': 'route53-recovery-cluster',
#  'Amazon Route 53 Recovery Controls': 'route53-recovery-control-config',
#  'Amazon Route 53 Recovery Readiness': 'route53-recovery-readiness',
#  'Amazon Route 53 Resolver': 'route53resolver',
#  'Amazon S3': 's3',
#  'Amazon S3 Object Lambda': 's3-object-lambda',
#  'Amazon S3 on Outposts': 's3-outposts',
#  'Amazon SageMaker': 'sagemaker',
#  'AWS Savings Plans': 'savingsplans',
#  'AWS Secrets Manager': 'secretsmanager',
#  'AWS Security Hub': 'securityhub',
#  'AWS Security Token Service': 'sts',
#  'AWS Server Migration Service': 'sms',
#  'AWS Serverless Application Repository': 'serverlessrepo',
#  'AWS Service Catalog': 'servicecatalog',
#  'AWS Service Quotas': 'servicequotas',
#  'Amazon SES': 'ses',
#  'Amazon Session Manager Message Gateway Service': 'ssmmessages',
#  'AWS Shield': 'shield',
#  'AWS Signer': 'signer',
#  'Amazon Simple Email Service v2': 'ses',
#  'Amazon Simple Workflow Service': 'swf',
#  'Amazon SimpleDB': 'sdb',
#  'AWS Snow Device Management': 'snow-device-management',
#  'AWS Snowball': 'snowball',
#  'Amazon SNS': 'sns',
#  'AWS SQL Workbench': 'sqlworkbench',
#  'Amazon SQS': 'sqs',
#  'AWS SSO': 'sso',
#  'AWS SSO Directory': 'sso-directory',
#  'AWS Step Functions': 'states',
#  'Amazon Storage Gateway': 'storagegateway',
#  'Amazon Sumerian': 'sumerian',
#  'AWS Support': 'support',
#  'AWS Systems Manager': 'ssm',
#  'AWS Systems Manager Incident Manager': 'ssm-incidents',
#  'AWS Systems Manager Incident Manager Contacts': 'ssm-contacts',
#  'AWS Tag Editor': 'resource-explorer',
#  'Amazon Textract': 'textract',
#  'Amazon Timestream': 'timestream',
#  'AWS Tiros': 'tiros',
#  'Amazon Transcribe': 'transcribe',
#  'AWS Transfer Family': 'transfer',
#  'Amazon Translate': 'translate',
#  'AWS Trusted Advisor': 'trustedadvisor',
#  'AWS WAF': 'waf',
#  'AWS WAF Regional': 'waf-regional',
#  'AWS WAF V2': 'wafv2',
#  'AWS Well-Architected Tool': 'wellarchitected',
#  'Amazon WorkDocs': 'workdocs',
#  'Amazon WorkLink': 'worklink',
#  'Amazon WorkMail': 'workmail',
#  'Amazon WorkMail Message Flow': 'workmailmessageflow',
#  'Amazon WorkSpaces': 'workspaces',
#  'Amazon WorkSpaces Application Manager': 'wam',
#  'AWS X-Ray': 'xray'}

# %%
len(action_name_to_prefix_mapping.keys())
# Out:
# 299

# %%
dump_json("dumps/aws_actions_name_to_prefix.json", action_name_to_prefix_mapping)
